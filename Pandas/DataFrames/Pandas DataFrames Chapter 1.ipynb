# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating Dictionary

# %%
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
                               'Mahindra', 'Maruti', 'Hyundai',
                               'Renault', 'Tata', 'Maruti'],
                     'Year': [2012, 2014, 2011, 2015, 2012,
                              2016, 2014, 2018, 2019],
                     'Kms Driven': [50000, 30000, 60000,
                                    25000, 10000, 46000,
                                    31000, 15000, 12000],
                     'City': ['Gurgaon', 'Delhi', 'Mumbai',
                              'Delhi', 'Mumbai', 'Delhi',
                              'Mumbai', 'Chennai',  'Ghaziabad'],
                     'Mileage':  [28, 27, 25, 26, 28,
                                  29, 24, 21, 24]})

# %% [markdown]
# # Changing Dictionary to DataFrame

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Adding additonal column in dataframe

# %%
df['Updates'] = 'No updates'

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 0    Maruti  2012       50000    Gurgaon       28  No updates
# 1   Hyundai  2014       30000      Delhi       27  No updates
# 2      Tata  2011       60000     Mumbai       25  No updates
# 3  Mahindra  2015       25000      Delhi       26  No updates
# 4    Maruti  2012       10000     Mumbai       28  No updates
# 5   Hyundai  2016       46000      Delhi       29  No updates
# 6   Renault  2014       31000     Mumbai       24  No updates
# 7      Tata  2018       15000    Chennai       21  No updates
# 8    Maruti  2019       12000  Ghaziabad       24  No updates

# %% [markdown]
# # Changing index for dataframe

# %%
df.index = [1,2,3,4,5,6,7,8,9]

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 2   Hyundai  2014       30000      Delhi       27  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 5    Maruti  2012       10000     Mumbai       28  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %% [markdown]
# # Accesing data

# %%
df["Kms Driven"]
# Out:
# 1    50000
# 2    30000
# 3    60000
# 4    25000
# 5    10000
# 6    46000
# 7    31000
# 8    15000
# 9    12000
# Name: Kms Driven, dtype: int64

# %%
df[:]['Year']
# Out:
# 1    2012
# 2    2014
# 3    2011
# 4    2015
# 5    2012
# 6    2016
# 7    2014
# 8    2018
# 9    2019
# Name: Year, dtype: int64

# %%
df[2:3]
# Out:
#   Brand  Year  Kms Driven    City  Mileage     Updates
# 3  Tata  2011       60000  Mumbai       25  No updates

# %%
df[::3]
# Out:
#       Brand  Year  Kms Driven     City  Mileage     Updates
# 1    Maruti  2012       50000  Gurgaon       28  No updates
# 4  Mahindra  2015       25000    Delhi       26  No updates
# 7   Renault  2014       31000   Mumbai       24  No updates

# %%
df[2:5]
# Out:
#       Brand  Year  Kms Driven    City  Mileage     Updates
# 3      Tata  2011       60000  Mumbai       25  No updates
# 4  Mahindra  2015       25000   Delhi       26  No updates
# 5    Maruti  2012       10000  Mumbai       28  No updates

# %%
df[2:4]["Brand"]
# Out:
# 3        Tata
# 4    Mahindra
# Name: Brand, dtype: object

# %%
df['City']
# Out:
# 1      Gurgaon
# 2        Delhi
# 3       Mumbai
# 4        Delhi
# 5       Mumbai
# 6        Delhi
# 7       Mumbai
# 8      Chennai
# 9    Ghaziabad
# Name: City, dtype: object

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 2   Hyundai  2014       30000      Delhi       27  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 5    Maruti  2012       10000     Mumbai       28  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %%
df["Brand"] == "Maruti"
# Out:
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9     True
# Name: Brand, dtype: bool

# %%
df[df["Brand"] == "Maruti"]
# Out:
#     Brand  Year  Kms Driven       City  Mileage     Updates
# 1  Maruti  2012       50000    Gurgaon       28  No updates
# 5  Maruti  2012       10000     Mumbai       28  No updates
# 9  Maruti  2019       12000  Ghaziabad       24  No updates

# %%
df['Kms Driven'] > 10000
# Out:
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Kms Driven, dtype: bool

# %%
df[df['Kms Driven'] > 10000]
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 2   Hyundai  2014       30000      Delhi       27  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 2   Hyundai  2014       30000      Delhi       27  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 5    Maruti  2012       10000     Mumbai       28  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 2   Hyundai  2014       30000      Delhi       27  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 5    Maruti  2012       10000     Mumbai       28  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %%
df['City'] == "Delhi"
# Out:
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: City, dtype: bool

# %%
df[df['City'] == 'Delhi']
# Out:
#       Brand  Year  Kms Driven   City  Mileage     Updates
# 2   Hyundai  2014       30000  Delhi       27  No updates
# 4  Mahindra  2015       25000  Delhi       26  No updates
# 6   Hyundai  2016       46000  Delhi       29  No updates

# %%
df.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64')

# %%
df.columns
# Out:
# Index(['Brand', 'Year', 'Kms Driven', 'City', 'Mileage', 'Updates'], dtype='object')

# %%
df['Brand'].dtype
# Out:
# dtype('O')

# %%
df["Kms Driven"].dtype
# Out:
# dtype('int64')

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 2   Hyundai  2014       30000      Delhi       27  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 5    Maruti  2012       10000     Mumbai       28  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %% [markdown]
# # Deleting rows or col

# %%
del df['Updates']

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
df['Updates'] = "No updates"

# %%
df
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 2   Hyundai  2014       30000      Delhi       27  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 5    Maruti  2012       10000     Mumbai       28  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %%
dff = df.copy()

# %%
dff
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 2   Hyundai  2014       30000      Delhi       27  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 5    Maruti  2012       10000     Mumbai       28  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %%
del dff["City"]

# %%
dff
# Out:
#       Brand  Year  Kms Driven  Mileage     Updates
# 1    Maruti  2012       50000       28  No updates
# 2   Hyundai  2014       30000       27  No updates
# 3      Tata  2011       60000       25  No updates
# 4  Mahindra  2015       25000       26  No updates
# 5    Maruti  2012       10000       28  No updates
# 6   Hyundai  2016       46000       29  No updates
# 7   Renault  2014       31000       24  No updates
# 8      Tata  2018       15000       21  No updates
# 9    Maruti  2019       12000       24  No updates

# %%
dff.drop('Updates', axis = 1)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
dff
# Out:
#       Brand  Year  Kms Driven  Mileage     Updates
# 1    Maruti  2012       50000       28  No updates
# 2   Hyundai  2014       30000       27  No updates
# 3      Tata  2011       60000       25  No updates
# 4  Mahindra  2015       25000       26  No updates
# 5    Maruti  2012       10000       28  No updates
# 6   Hyundai  2016       46000       29  No updates
# 7   Renault  2014       31000       24  No updates
# 8      Tata  2018       15000       21  No updates
# 9    Maruti  2019       12000       24  No updates

# %%
dff
# Out:
#       Brand  Year  Kms Driven  Mileage     Updates
# 1    Maruti  2012       50000       28  No updates
# 2   Hyundai  2014       30000       27  No updates
# 3      Tata  2011       60000       25  No updates
# 4  Mahindra  2015       25000       26  No updates
# 5    Maruti  2012       10000       28  No updates
# 6   Hyundai  2016       46000       29  No updates
# 7   Renault  2014       31000       24  No updates
# 8      Tata  2018       15000       21  No updates
# 9    Maruti  2019       12000       24  No updates

# %%
dff.drop(2, axis= 0)
# Out:
#       Brand  Year  Kms Driven       City  Mileage     Updates
# 1    Maruti  2012       50000    Gurgaon       28  No updates
# 3      Tata  2011       60000     Mumbai       25  No updates
# 4  Mahindra  2015       25000      Delhi       26  No updates
# 5    Maruti  2012       10000     Mumbai       28  No updates
# 6   Hyundai  2016       46000      Delhi       29  No updates
# 7   Renault  2014       31000     Mumbai       24  No updates
# 8      Tata  2018       15000    Chennai       21  No updates
# 9    Maruti  2019       12000  Ghaziabad       24  No updates

# %%
dff
# Out:
#       Brand  Year  Kms Driven  Mileage     Updates
# 1    Maruti  2012       50000       28  No updates
# 2   Hyundai  2014       30000       27  No updates
# 3      Tata  2011       60000       25  No updates
# 4  Mahindra  2015       25000       26  No updates
# 5    Maruti  2012       10000       28  No updates
# 6   Hyundai  2016       46000       29  No updates
# 7   Renault  2014       31000       24  No updates
# 8      Tata  2018       15000       21  No updates
# 9    Maruti  2019       12000       24  No updates

# %%
dff.drop(7,axis = 0)
# Out:
#       Brand  Year  Kms Driven  Mileage     Updates
# 1    Maruti  2012       50000       28  No updates
# 2   Hyundai  2014       30000       27  No updates
# 3      Tata  2011       60000       25  No updates
# 4  Mahindra  2015       25000       26  No updates
# 5    Maruti  2012       10000       28  No updates
# 6   Hyundai  2016       46000       29  No updates
# 8      Tata  2018       15000       21  No updates
# 9    Maruti  2019       12000       24  No updates

# %%
df.head()
# Out:
#       Brand  Year  Kms Driven     City  Mileage     Updates
# 1    Maruti  2012       50000  Gurgaon       28  No updates
# 2   Hyundai  2014       30000    Delhi       27  No updates
# 3      Tata  2011       60000   Mumbai       25  No updates
# 4  Mahindra  2015       25000    Delhi       26  No updates
# 5    Maruti  2012       10000   Mumbai       28  No updates

# %%
df.tail()
# Out:
#      Brand  Year  Kms Driven       City  Mileage     Updates
# 5   Maruti  2012       10000     Mumbai       28  No updates
# 6  Hyundai  2016       46000      Delhi       29  No updates
# 7  Renault  2014       31000     Mumbai       24  No updates
# 8     Tata  2018       15000    Chennai       21  No updates
# 9   Maruti  2019       12000  Ghaziabad       24  No updates
