# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
air_quality = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2.csv", index_col=0, parse_dates=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_values(by = "Age")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
pd.DataFrame(titanic.groupby('Sex'))[1].values[1]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.tail(2)
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN

# %%
titanic.sort_values(by='Age').dropna()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 305          306         1       1        Allison, Master. Hudson Trevor
# 183          184         1       2             Becker, Master. Richard F
# 297          298         0       1          Allison, Miss. Helen Loraine
# 205          206         0       3            Strom, Miss. Telma Matilda
# 340          341         1       2        Navratil, Master. Edmond Roger
# ..           ...       ...     ...                                   ...
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 456          457         0       1             Millet, Mr. Francis Davis
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 96            97         0       1             Goldschmidt, Mr. George B
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex    Age  SibSp  Parch     Ticket      Fare    Cabin Embarked
# ...

# %%
titanic.Age.isnull().value_counts()
# Out:
# False    714
# True     177
# Name: Age, dtype: int64

# %%
pd.DataFrame(titanic.Cabin.value_counts(dropna=False))
# Out:
#              Cabin
# NaN            687
# C23 C25 C27      4
# G6               4
# B96 B98          4
# C22 C26          3
# ...            ...
# E34              1
# C7               1
# C54              1
# E36              1
# C148             1
#
# [148 rows x 1 columns]

# %%
titanic.Age.value_counts(dropna=False)
# Out:
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: Age, Length: 89, dtype: int64

# %%
pd.DataFrame(titanic.groupby('Sex').value_counts())
# Out:
#                                                                                                                                                0
# Sex    PassengerId Survived Pclass Name                                               Age  SibSp Parch Ticket   Fare     Cabin       Embarked
# female 2           1        1      Cumings, Mrs. John Bradley (Florence Briggs Tha... 38.0 1     0     PC 17599 71.2833  C85         C         1
#        4           1        1      Futrelle, Mrs. Jacques Heath (Lily May Peel)       35.0 1     0     113803   53.1000  C123        S         1
#        298         0        1      Allison, Miss. Helen Loraine                       2.0  1     2     113781   151.5500 C22 C26     S         1
#        308         1        1      Penasco y Castellana, Mrs. Victor de Satode (Ma... 17.0 1     0     PC 17758 108.9000 C65         C         1
# ...

# %%
pd.DataFrame(titanic.sort_values(by='Age').groupby('Sex'))[1].values[0]
# Out:
#      PassengerId  Survived  Pclass  \
# 644          645         1       3
# 469          470         1       3
# 381          382         1       3
# 172          173         1       3
# 642          643         0       3
# ..           ...       ...     ...
# 727          728         1       3
# 792          793         0       3
# 849          850         1       1
# 863          864         0       3
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 644                        Baclini, Miss. Eugenie  female  0.75      2      1
# 469                 Baclini, Miss. Helene Barbara  female  0.75      2      1
# 381                   Nakid, Miss. Maria ("Mary")  female  1.00      0      2
# 172                  Johnson, Miss. Eleanor Ileen  female  1.00      1      1
# 642                 Skoog, Miss. Margit Elizabeth  female  2.00      3      2
# ...

# %%
pd.DataFrame(titanic.sort_values(by='Age').groupby('Sex'))[1].values[1]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
# 755          756         1       2        Hamalainen, Master. Viljo  male
# 78            79         1       2    Caldwell, Master. Alden Gates  male
# 831          832         1       2  Richards, Master. George Sibley  male
# 305          306         1       1   Allison, Master. Hudson Trevor  male
# ..           ...       ...     ...                              ...   ...
# 839          840         1       1             Marechal, Mr. Pierre  male
# 846          847         0       3         Sage, Mr. Douglas Bullen  male
# 859          860         0       3                 Razi, Mr. Raihed  male
# 868          869         0       3      van Melkebeke, Mr. Philemon  male
# 878          879         0       3               Laleff, Mr. Kristo  male
#
#       Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# ...

# %%
titanic[titanic['Sex'] == 'female'].max()
# Out:
# C:\Users\GOHAR\AppData\Local\Temp\ipykernel_13748\844890357.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic[titanic['Sex'] == 'female'].max()
# PassengerId                                             889
# Survived                                                  1
# Pclass                                                    3
# Name           de Messemaeker, Mrs. Guillaume Joseph (Emma)
# Sex                                                  female
# Age                                                    63.0
# SibSp                                                     8
# Parch                                                     6
# Ticket                                            WE/P 5735
# Fare                                               512.3292
# dtype: object

# %%
titanic[titanic['Sex'] == 'male'].max()
# Out:
# C:\Users\GOHAR\AppData\Local\Temp\ipykernel_13748\3982352804.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic[titanic['Sex'] == 'male'].max()
# PassengerId                            891
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                   80.0
# SibSp                                    8
# Parch                                    5
# Ticket                           WE/P 5735
# Fare                              512.3292
# Embarked                                 S
# dtype: object

# %%
titanic.sort_values(by = 'Age').dropna(subset='Age').tail()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 630  male  80.0      0      0     27042  30.0000   A23        S

# %%
pd.DataFrame(titanic.groupby(['Pclass','Sex'])['Age'].max())
# Out:
#                 Age
# Pclass Sex
# 1      female  63.0
#        male    80.0
# 2      female  57.0
#        male    70.0
# 3      female  63.0
#        male    74.0

# %%
pd.DataFrame(titanic.groupby(['Pclass','Sex'])['Age','PassengerId'].max())
# Out:
# C:\Users\GOHAR\AppData\Local\Temp\ipykernel_13748\149134030.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pd.DataFrame(titanic.groupby(['Pclass','Sex'])['Age','PassengerId'].max())
#                 Age  PassengerId
# Pclass Sex
# 1      female  63.0          888
#        male    80.0          890
# 2      female  57.0          881
#        male    70.0          887
# 3      female  63.0          889
#        male    74.0          891

# %%
pd.DataFrame(titanic.groupby(['Pclass','Sex'])['Age'].agg([max]).unstack())
# Out:
#           max
# Sex    female  male
# Pclass
# 1        63.0  80.0
# 2        57.0  70.0
# 3        63.0  74.0

# %%
titanic.sort_values(['Pclass','Age'],ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 851          852         0       3
# 116          117         0       3
# 280          281         0       3
# 483          484         1       3
# 326          327         0       3
# ..           ...       ...     ...
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 851                           Svensson, Mr. Johan    male  74.0      0      0
# 116                          Connors, Mr. Patrick    male  70.5      0      0
# 280                              Duane, Mr. Frank    male  65.0      0      0
# 483                        Turkula, Mrs. (Hedwig)  female  63.0      0      0
# 326                     Nysveen, Mr. Johan Hansen    male  61.0      0      0
# ...

# %%
titanic.sort_values(['Pclass','Age'] , ascending=([False,True]))
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 469          470         1       3
# 644          645         1       3
# 164          165         0       3
# 172          173         1       3
# ..           ...       ...     ...
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 803               Thomas, Master. Assad Alexander    male  0.42      0      1
# 469                 Baclini, Miss. Helene Barbara  female  0.75      2      1
# 644                        Baclini, Miss. Eugenie  female  0.75      2      1
# 164                  Panula, Master. Eino Viljami    male  1.00      4      1
# 172                  Johnson, Miss. Eleanor Ileen  female  1.00      1      1
# ...

# %%
air_quality = pd.read_csv(
    "https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_long.csv", 
    index_col='date.utc',
    parse_dates=True
)
air_quality
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801      pm25
# ...                              ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# ...

# %%
no2 = air_quality[air_quality['parameter'] == 'no2']

# %%
no2_subset = no2.sort_values(by='date.utc').groupby('location').head(2)
no2_subset
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-04-09 01:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 01:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 02:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# 2019-04-09 01:00:00+00:00   22.5  µg/m³
# 2019-04-09 01:00:00+00:00   24.4  µg/m³
# 2019-04-09 02:00:00+00:00   67.0  µg/m³
# 2019-04-09 02:00:00+00:00   53.5  µg/m³
# 2019-04-09 02:00:00+00:00   27.4  µg/m³
# 2019-04-09 03:00:00+00:00   67.0  µg/m³

# %%
no2.location.value_counts()
# Out:
# FR04014               1676
# London Westminster    1608
# BETR801                163
# Name: location, dtype: int64

# %%
pd.DataFrame(no2.groupby(['date.utc','location'])['value'].max()).unstack()
# Out:
#                             value
# location                  BETR801 FR04014 London Westminster
# date.utc
# 2019-04-09 01:00:00+00:00    22.5    24.4                NaN
# 2019-04-09 02:00:00+00:00    53.5    27.4               67.0
# 2019-04-09 03:00:00+00:00    54.5    34.2               67.0
# 2019-04-09 04:00:00+00:00    34.5    48.5               41.0
# 2019-04-09 05:00:00+00:00    46.5    59.5               41.0
# ...                           ...     ...                ...
# 2019-06-20 20:00:00+00:00     NaN    21.4                NaN
# 2019-06-20 21:00:00+00:00     NaN    24.9                NaN
# 2019-06-20 22:00:00+00:00     NaN    26.5                NaN
# 2019-06-20 23:00:00+00:00     NaN    21.8                NaN
# 2019-06-21 00:00:00+00:00     NaN    20.0                NaN
#
# [1705 rows x 3 columns]

# %%
no2.pivot(columns='location',values='value')
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2019-04-09 03:00:00+00:00     54.5     34.2                67.0
# 2019-04-09 04:00:00+00:00     34.5     48.5                41.0
# 2019-04-09 05:00:00+00:00     46.5     59.5                41.0
# ...                            ...      ...                 ...
# 2019-06-20 20:00:00+00:00      NaN     21.4                 NaN
# 2019-06-20 21:00:00+00:00      NaN     24.9                 NaN
# 2019-06-20 22:00:00+00:00      NaN     26.5                 NaN
# 2019-06-20 23:00:00+00:00      NaN     21.8                 NaN
# 2019-06-21 00:00:00+00:00      NaN     20.0                 NaN
#
# [1705 rows x 3 columns]

# %%
no2.pivot(columns='location',values='country')
# Out:
# location                  BETR801 FR04014 London Westminster
# date.utc
# 2019-04-09 01:00:00+00:00      BE      FR                NaN
# 2019-04-09 02:00:00+00:00      BE      FR                 GB
# 2019-04-09 03:00:00+00:00      BE      FR                 GB
# 2019-04-09 04:00:00+00:00      BE      FR                 GB
# 2019-04-09 05:00:00+00:00      BE      FR                 GB
# ...                           ...     ...                ...
# 2019-06-20 20:00:00+00:00     NaN      FR                NaN
# 2019-06-20 21:00:00+00:00     NaN      FR                NaN
# 2019-06-20 22:00:00+00:00     NaN      FR                NaN
# 2019-06-20 23:00:00+00:00     NaN      FR                NaN
# 2019-06-21 00:00:00+00:00     NaN      FR                NaN
#
# [1705 rows x 3 columns]

# %%
no2.pivot(columns=['city'],values=['value','unit'])
# Out:
#                               value                   unit
# city                      Antwerpen London Paris Antwerpen London  Paris
# date.utc
# 2019-04-09 01:00:00+00:00      22.5    NaN  24.4     µg/m³    NaN  µg/m³
# 2019-04-09 02:00:00+00:00      53.5   67.0  27.4     µg/m³  µg/m³  µg/m³
# 2019-04-09 03:00:00+00:00      54.5   67.0  34.2     µg/m³  µg/m³  µg/m³
# 2019-04-09 04:00:00+00:00      34.5   41.0  48.5     µg/m³  µg/m³  µg/m³
# 2019-04-09 05:00:00+00:00      46.5   41.0  59.5     µg/m³  µg/m³  µg/m³
# ...                             ...    ...   ...       ...    ...    ...
# 2019-06-20 20:00:00+00:00       NaN    NaN  21.4       NaN    NaN  µg/m³
# 2019-06-20 21:00:00+00:00       NaN    NaN  24.9       NaN    NaN  µg/m³
# 2019-06-20 22:00:00+00:00       NaN    NaN  26.5       NaN    NaN  µg/m³
# 2019-06-20 23:00:00+00:00       NaN    NaN  21.8       NaN    NaN  µg/m³
# 2019-06-21 00:00:00+00:00       NaN    NaN  20.0       NaN    NaN  µg/m³
#
# [1705 rows x 6 columns]

# %%
no2.pivot(columns='location',values='value').plot(figsize = (12,6))
# Out:
# <AxesSubplot:xlabel='date.utc'>

# %%
air_quality.pivot_table(values='value',aggfunc=['mean','max'],columns='parameter',index='location')
# Out:
#                          mean               max
# parameter                 no2       pm25    no2  pm25
# location
# BETR801             26.950920  23.169492   74.5  99.0
# FR04014             29.374284        NaN  117.2   NaN
# London Westminster  29.740050  13.443568   97.0  55.0

# %%
air_quality.pivot_table(values='value',columns='parameter',index='location',aggfunc=['mean','median','max','min'],margins=True)
# Out:
#                          mean                       median               \
# parameter                 no2       pm25        All    no2  pm25    All
# location
# BETR801             26.950920  23.169492  24.982353   25.0  18.5  22.25
# FR04014             29.374284        NaN  29.374284   26.1   NaN  26.10
# London Westminster  29.740050  13.443568  21.491708   28.0   9.0  19.00
# All                 29.430316  14.386849  24.222743   27.0  10.0  22.00
#
#                       max               min
# parameter             no2  pm25    All  no2 pm25  All
# location
# BETR801              74.5  99.0   99.0  7.5  3.0  3.0
# FR04014             117.2   NaN  117.2  0.0  NaN  0.0
# London Westminster   97.0  55.0   97.0  0.0  5.0  0.0
# All                 117.2  99.0  117.2  0.0  3.0  0.0

# %%
air_quality.location.value_counts()
# Out:
# London Westminster    3256
# FR04014               1676
# BETR801                340
# Name: location, dtype: int64

# %%
pd.DataFrame(air_quality.groupby('location')['value'].agg('mean'))
# Out:
#                         value
# location
# BETR801             24.982353
# FR04014             29.374284
# London Westminster  21.491708

# %%
air_quality.groupby(['parameter','location']).mean()
# Out:
#                                   value
# parameter location
# no2       BETR801             26.950920
#           FR04014             29.374284
#           London Westminster  29.740050
# pm25      BETR801             23.169492
#           London Westminster  13.443568

# %%
air_quality.groupby(['parameter','location']).mean().unstack()
# Out:
#                value
# location     BETR801    FR04014 London Westminster
# parameter
# no2        26.950920  29.374284          29.740050
# pm25       23.169492        NaN          13.443568

# %%
no2.pivot(values='value',columns='location').reset_index()
# Out:
# location                  date.utc  BETR801  FR04014  London Westminster
# 0        2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 1        2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2        2019-04-09 03:00:00+00:00     54.5     34.2                67.0
# 3        2019-04-09 04:00:00+00:00     34.5     48.5                41.0
# 4        2019-04-09 05:00:00+00:00     46.5     59.5                41.0
# ...                            ...      ...      ...                 ...
# 1700     2019-06-20 20:00:00+00:00      NaN     21.4                 NaN
# 1701     2019-06-20 21:00:00+00:00      NaN     24.9                 NaN
# 1702     2019-06-20 22:00:00+00:00      NaN     26.5                 NaN
# 1703     2019-06-20 23:00:00+00:00      NaN     21.8                 NaN
# 1704     2019-06-21 00:00:00+00:00      NaN     20.0                 NaN
#
# [1705 rows x 4 columns]

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic.Name.str.contains('Miss')]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 2              3         1       3                    Heikkinen, Miss. Laina
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 11            12         1       1                  Bonnell, Miss. Elizabeth
# 14            15         0       3      Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                       ...
# 866          867         1       2              Duran y More, Miss. Asuncion
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic[titanic.Name.str.lower().str.contains('miss')]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 2              3         1       3                    Heikkinen, Miss. Laina
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 11            12         1       1                  Bonnell, Miss. Elizabeth
# 14            15         0       3      Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                       ...
# 866          867         1       2              Duran y More, Miss. Asuncion
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
print(titanic.Name.str.len().max())
print(titanic.Name.str.len().idxmax())
# Out:
# 82
# 307

# %%
titanic.loc[titanic.Name.str.len() == 82,'Name']
# Out:
# 307    Penasco y Castellana, Mrs. Victor de Satode (M...
# Name: Name, dtype: object

# %%
titanic[titanic.Name.str.len() == 82]
# Out:
#      PassengerId  Survived  Pclass  \
# 307          308         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
#
#      Parch    Ticket   Fare Cabin Embarked
# 307      0  PC 17758  108.9   C65        C

# %%
air_quality_no2 = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2_long.csv",
                             parse_dates=True)
air_quality_no2 = air_quality_no2[["date.utc", "location",
                                   "parameter", "value"]]
air_quality_no2
# Out:
#                        date.utc            location parameter  value
# 0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
# 1     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 2     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
# 3     2019-06-20 21:00:00+00:00             FR04014       no2   24.9
# 4     2019-06-20 20:00:00+00:00             FR04014       no2   21.4
# ...                         ...                 ...       ...    ...
# 2063  2019-05-07 06:00:00+00:00  London Westminster       no2   26.0
# 2064  2019-05-07 04:00:00+00:00  London Westminster       no2   16.0
# 2065  2019-05-07 03:00:00+00:00  London Westminster       no2   19.0
# 2066  2019-05-07 02:00:00+00:00  London Westminster       no2   19.0
# 2067  2019-05-07 01:00:00+00:00  London Westminster       no2   23.0
#
# [2068 rows x 4 columns]

# %%
air_quality_pm25 = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_pm25_long.csv",
                               parse_dates=True)
air_quality_pm25 = air_quality_pm25[["date.utc", "location",
                                     "parameter", "value"]]

print(len(air_quality_pm25))
air_quality_pm25.head()
# Out:
# 1110
#                     date.utc location parameter  value
# 0  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5

# %%
new = pd.concat([air_quality_no2,air_quality_pm25])
display(new)
print("Air Quality Nitrogen di oxide length : ",len(air_quality_no2))
print("Air Quality pm25 length : ",len(air_quality_pm25))
print("Length of concatenation of air quality blw teo dataframes : ",len(pd.concat([air_quality_no2,air_quality_pm25])))
print('Sum of no2 and pm25 length : ',len(air_quality_no2)+len(air_quality_pm25))
# Out:
#                        date.utc            location parameter  value
# 0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
# 1     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 2     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
# 3     2019-06-20 21:00:00+00:00             FR04014       no2   24.9
# 4     2019-06-20 20:00:00+00:00             FR04014       no2   21.4
# ...                         ...                 ...       ...    ...
# 1105  2019-05-07 06:00:00+00:00  London Westminster      pm25    9.0
# 1106  2019-05-07 04:00:00+00:00  London Westminster      pm25    8.0
# 1107  2019-05-07 03:00:00+00:00  London Westminster      pm25    8.0
# 1108  2019-05-07 02:00:00+00:00  London Westminster      pm25    8.0
# 1109  2019-05-07 01:00:00+00:00  London Westminster      pm25    8.0
#
# [3178 rows x 4 columns]
# Air Quality Nitrogen di oxide length :  2068
# Air Quality pm25 length :  1110
# ...

# %%
pd.concat([air_quality_no2,air_quality_pm25],keys=['no2','pm25'])
# Out:
#                             date.utc            location parameter  value
# no2  0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
#      1     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
#      2     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
#      3     2019-06-20 21:00:00+00:00             FR04014       no2   24.9
#      4     2019-06-20 20:00:00+00:00             FR04014       no2   21.4
# ...                              ...                 ...       ...    ...
# pm25 1105  2019-05-07 06:00:00+00:00  London Westminster      pm25    9.0
#      1106  2019-05-07 04:00:00+00:00  London Westminster      pm25    8.0
#      1107  2019-05-07 03:00:00+00:00  London Westminster      pm25    8.0
#      1108  2019-05-07 02:00:00+00:00  London Westminster      pm25    8.0
#      1109  2019-05-07 01:00:00+00:00  London Westminster      pm25    8.0
#
# [3178 rows x 4 columns]

# %%
stations_coord = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_stations.csv")
print(len(stations_coord))
stations_coord.head()
# Out:
# 66
#   location  coordinates.latitude  coordinates.longitude
# 0  BELAL01              51.23619                4.38522
# 1  BELHB23              51.17030                4.34100
# 2  BELLD01              51.10998                5.00486
# 3  BELLD02              51.12038                5.02155
# 4  BELR833              51.32766                4.36226

# %%
print(len(stations_coord.value_counts()))
stations_coord.location.value_counts(dropna=False)
# Out:
# 66
# FR04118                              2
# FR04071                              2
# FR04031                              2
# FR04014                              2
# FR04135                              2
# FR04141                              2
# FR04143                              2
# FR04329                              2
# FR04131                              1
# FR04179                              1
# Camden Kerbside                      1
# Ealing Horn Lane                     1
# Haringey Roadside                    1
# London Bexley                        1
# London Bloomsbury                    1
# BELAL01                              1
# London Haringey Priory Park South    1
# London Harlington                    1
# London Harrow Stanmore               1
# London Hillingdon                    1
# London Marylebone Road               1
# London N. Kensington                 1
# London Teddington                    1
# London Teddington Bushy Park         1
# ...

# %%
air_quality.location.value_counts(dropna=False)
# Out:
# London Westminster    3256
# FR04014               1676
# BETR801                340
# Name: location, dtype: int64

# %%
stations_coord
# Out:
#                       location  coordinates.latitude  coordinates.longitude
# 0                      BELAL01              51.23619                4.38522
# 1                      BELHB23              51.17030                4.34100
# 2                      BELLD01              51.10998                5.00486
# 3                      BELLD02              51.12038                5.02155
# 4                      BELR833              51.32766                4.36226
# ..                         ...                   ...                    ...
# 61             Southend-on-Sea              51.54420                0.67841
# 62  Southwark A2 Old Kent Road              51.48050               -0.05955
# 63                    Thurrock              51.47707                0.31797
# 64      Tower Hamlets Roadside              51.52253               -0.04216
# 65        Groton Fort Griswold              41.35360              -72.07890
#
# [66 rows x 3 columns]

# %%
air_quality
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801      pm25
# ...                              ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# ...

# %%
air_quality = air_quality.reset_index()
air_quality
# Out:
#       index                  date.utc       city country            location  \
# 0         0 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801
# 1         1 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801
# 2         2 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801
# 3         3 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801
# 4         4 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801
# ...     ...                       ...        ...     ...                 ...
# 5267   5267 2019-04-09 06:00:00+00:00     London      GB  London Westminster
# 5268   5268 2019-04-09 05:00:00+00:00     London      GB  London Westminster
# 5269   5269 2019-04-09 04:00:00+00:00     London      GB  London Westminster
# 5270   5270 2019-04-09 03:00:00+00:00     London      GB  London Westminster
# 5271   5271 2019-04-09 02:00:00+00:00     London      GB  London Westminster
#
#      parameter  value   unit
# ...

# %%
air_quality = air_quality[['date.utc','location','parameter','value']]
air_quality
# Out:
#                       date.utc            location parameter  value
# 0    2019-06-18 06:00:00+00:00             BETR801      pm25   18.0
# 1    2019-06-17 08:00:00+00:00             BETR801      pm25    6.5
# 2    2019-06-17 07:00:00+00:00             BETR801      pm25   18.5
# 3    2019-06-17 06:00:00+00:00             BETR801      pm25   16.0
# 4    2019-06-17 05:00:00+00:00             BETR801      pm25    7.5
# ...                        ...                 ...       ...    ...
# 5267 2019-04-09 06:00:00+00:00  London Westminster       no2   41.0
# 5268 2019-04-09 05:00:00+00:00  London Westminster       no2   41.0
# 5269 2019-04-09 04:00:00+00:00  London Westminster       no2   41.0
# 5270 2019-04-09 03:00:00+00:00  London Westminster       no2   67.0
# 5271 2019-04-09 02:00:00+00:00  London Westminster       no2   67.0
#
# [5272 rows x 4 columns]

# %%
air_quality.location.value_counts()
# Out:
# London Westminster    3256
# FR04014               1676
# BETR801                340
# Name: location, dtype: int64

# %%
stations_coord.location.value_counts()
# Out:
# FR04118                              2
# FR04071                              2
# FR04031                              2
# FR04014                              2
# FR04135                              2
# FR04141                              2
# FR04143                              2
# FR04329                              2
# FR04131                              1
# FR04179                              1
# Camden Kerbside                      1
# Ealing Horn Lane                     1
# Haringey Roadside                    1
# London Bexley                        1
# London Bloomsbury                    1
# BELAL01                              1
# London Haringey Priory Park South    1
# London Harlington                    1
# London Harrow Stanmore               1
# London Hillingdon                    1
# London Marylebone Road               1
# London N. Kensington                 1
# London Teddington                    1
# London Teddington Bushy Park         1
# ...

# %%
air_quality = pd.merge(air_quality,stations_coord,how='left',on='location')
air_quality
# Out:
#                        date.utc            location parameter  value  \
# 0     2019-06-18 06:00:00+00:00             BETR801      pm25   18.0
# 1     2019-06-17 08:00:00+00:00             BETR801      pm25    6.5
# 2     2019-06-17 07:00:00+00:00             BETR801      pm25   18.5
# 3     2019-06-17 06:00:00+00:00             BETR801      pm25   16.0
# 4     2019-06-17 05:00:00+00:00             BETR801      pm25    7.5
# ...                         ...                 ...       ...    ...
# 10295 2019-04-09 06:00:00+00:00  London Westminster       no2   41.0
# 10296 2019-04-09 05:00:00+00:00  London Westminster       no2   41.0
# 10297 2019-04-09 04:00:00+00:00  London Westminster       no2   41.0
# 10298 2019-04-09 03:00:00+00:00  London Westminster       no2   67.0
# 10299 2019-04-09 02:00:00+00:00  London Westminster       no2   67.0
#
#        coordinates.latitude_x  coordinates.longitude_x  \
# 0                    51.20966                  4.43182
# ...

# %%
air_quality_parameters = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_parameters.csv")

air_quality_parameters.head()
# Out:
#      id                                        description  name
# 0    bc                                       Black Carbon    BC
# 1    co                                    Carbon Monoxide    CO
# 2   no2                                   Nitrogen Dioxide   NO2
# 3    o3                                              Ozone    O3
# 4  pm10  Particulate matter less than 10 micrometers in...  PM10

# %%
stations_coord
# Out:
#                       location  coordinates.latitude  coordinates.longitude
# 0                      BELAL01              51.23619                4.38522
# 1                      BELHB23              51.17030                4.34100
# 2                      BELLD01              51.10998                5.00486
# 3                      BELLD02              51.12038                5.02155
# 4                      BELR833              51.32766                4.36226
# ..                         ...                   ...                    ...
# 61             Southend-on-Sea              51.54420                0.67841
# 62  Southwark A2 Old Kent Road              51.48050               -0.05955
# 63                    Thurrock              51.47707                0.31797
# 64      Tower Hamlets Roadside              51.52253               -0.04216
# 65        Groton Fort Griswold              41.35360              -72.07890
#
# [66 rows x 3 columns]

# %%
air_quality = pd.merge(air_quality,air_quality_parameters,how='left',left_on='parameter',right_on='id')
air_quality
# Out:
#                        date.utc            location parameter  value  \
# 0     2019-06-18 06:00:00+00:00             BETR801      pm25   18.0
# 1     2019-06-17 08:00:00+00:00             BETR801      pm25    6.5
# 2     2019-06-17 07:00:00+00:00             BETR801      pm25   18.5
# 3     2019-06-17 06:00:00+00:00             BETR801      pm25   16.0
# 4     2019-06-17 05:00:00+00:00             BETR801      pm25    7.5
# ...                         ...                 ...       ...    ...
# 10295 2019-04-09 06:00:00+00:00  London Westminster       no2   41.0
# 10296 2019-04-09 05:00:00+00:00  London Westminster       no2   41.0
# 10297 2019-04-09 04:00:00+00:00  London Westminster       no2   41.0
# 10298 2019-04-09 03:00:00+00:00  London Westminster       no2   67.0
# 10299 2019-04-09 02:00:00+00:00  London Westminster       no2   67.0
#
#        coordinates.latitude_x  coordinates.longitude_x  \
# 0                    51.20966                  4.43182
# ...
