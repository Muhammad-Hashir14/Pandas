# %%
import pandas as pd

# %%
data = pd.read_csv('cast.csv')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                           title  year                        name     type  \
# 0                Closet Monster  2015                    Buffy #1    actor
# 1               Suuri illusioni  1985                      Homo $    actor
# 2           Battle of the Sexes  2017                     $hutter    actor
# 3          Secret in Their Eyes  2015                     $hutter    actor
# 4                    Steve Jobs  2015                     $hutter    actor
# ...                         ...   ...                         ...      ...
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character     n
# ...

# %%
df.groupby([df['year'],'type']).size()
# Out:
# year  type
# 1912  actor       1
#       actress     2
# 1913  actor       9
#       actress     1
# 1914  actor      38
#                  ..
# 2019  actress     3
# 2020  actor       3
#       actress     1
# 2023  actor       1
#       actress     2
# Length: 220, dtype: int64

# %% [markdown]
# ## UnStack

# %%
c_decade = df.groupby([df['year'],'type']).size()

# %% [raw]
# c_decade

# %%
#Unstack changes groupes data to dataframe
c_decade.unstack()
# Out:
# type  actor  actress
# year
# 1912      1        2
# 1913      9        1
# 1914     38       23
# 1915     50       32
# 1916     57       59
# ...     ...      ...
# 2017   1418      741
# 2018     91       67
# 2019     13        3
# 2020      3        1
# 2023      1        2
#
# [110 rows x 2 columns]

# %%
graph = c_decade.unstack().head()

# %%
graph.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
decade = df.groupby(['type',df['year']]).size()

# %%
decade
# Out:
# type     year
# actor    1912      1
#          1913      9
#          1914     38
#          1915     50
#          1916     57
#                 ...
# actress  2017    741
#          2018     67
#          2019      3
#          2020      1
#          2023      2
# Length: 220, dtype: int64

# %%
frame = decade.unstack()

# %%
frame
# Out:
# year     1912  1913  1914  1915  1916  1917  1918  1919  1920  1921  ...  \
# type                                                                 ...
# actor       1     9    38    50    57    58    88    83    67    64  ...
# actress     2     1    23    32    59    59    45    64    60    48  ...
#
# year     2012  2013  2014  2015  2016  2017  2018  2019  2020  2023
# type
# actor    1919  1980  2094  2175  2424  1418    91    13     3     1
# actress  1092  1130  1215  1264  1417   741    67     3     1     2
#
# [2 rows x 110 columns]

# %%
graph = frame.iloc[:,0:9]

# %%
graph.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='type'>

# %% [markdown]
# ## Merge

# %%
df
# Out:
#                           title  year                        name     type  \
# 0                Closet Monster  2015                    Buffy #1    actor
# 1               Suuri illusioni  1985                      Homo $    actor
# 2           Battle of the Sexes  2017                     $hutter    actor
# 3          Secret in Their Eyes  2015                     $hutter    actor
# 4                    Steve Jobs  2015                     $hutter    actor
# ...                         ...   ...                         ...      ...
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character     n
# ...

# %%
df1 = pd.read_csv('release_dates.csv')

# %%
df1
# Out:
#                         title  year      country        date
# 0       #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                     #Beings  2015      Romania  2015-01-29
# 2                   #Declimax  2018  Netherlands  2018-01-21
# 3      #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 4                     #Horror  2015          USA  2015-11-20
# ...                       ...   ...          ...         ...
# 49995                 Botched  2007           UK  2008-04-18
# 49996                 Botched  2007         Peru  2010-01-21
# 49997    Bote, dyaryo, garapa  1989  Philippines  1989-05-26
# 49998    Both Barrels Blazing  1945          USA  1945-05-17
# 49999         Botika sa baryo  1960  Philippines  1960-09-23
#
# [50000 rows x 4 columns]

# %%
df[df['title'].isin(df1['title'])]
# Out:
#                       title  year                          name     type  \
# 14     All Out Dysfunktion!  2016         Kirlew 'bliss' Vilbon    actor
# 21                   B-Girl  2009          Jesse 'Casper' Brown    actor
# 22       Battle of the Year  2013          Jesse 'Casper' Brown    actor
# 61     All Out Dysfunktion!  2016       Seth 'Reaktion' Hillard    actor
# 66       Battle of the Year  2013  Rafael 'Spax' Szulc-Vollmann    actor
# ...                     ...   ...                           ...      ...
# 74939              13 Hours  2016              Elektra Anastasi  actress
# 74952  All Out Dysfunktion!  2016            Cernenco Anastasia  actress
# 74971               Akropol  1996            Maria Anastasiadou  actress
# 74994            180 moires  2010       Penelope Anastasopoulou  actress
# 74995      Ama de se thelei  2009       Penelope Anastasopoulou  actress
#
#           character     n
# 14            Bliss   NaN
# 21     Battle Judge  25.0
# ...

# %%
first = df1[df1['title'] == '13 Hours']

# %%
second = df[df['title'] == '13 Hours']

# %%
display(first)
# Out:
#          title  year                country        date
# 1488  13 Hours  2016            New Zealand  2016-01-14
# 1489  13 Hours  2016                 Panama  2016-01-14
# 1490  13 Hours  2016                   Peru  2016-01-14
# 1491  13 Hours  2016                  India  2016-01-15
# 1492  13 Hours  2016                    USA  2016-01-15
# 1493  13 Hours  2016              Venezuela  2016-01-15
# 1494  13 Hours  2016                  Egypt  2016-01-20
# 1495  13 Hours  2016             Azerbaijan  2016-01-21
# 1496  13 Hours  2016               Colombia  2016-01-21
# 1497  13 Hours  2016             Kazakhstan  2016-01-21
# 1498  13 Hours  2016                Lebanon  2016-01-21
# 1499  13 Hours  2016               Thailand  2016-01-21
# 1500  13 Hours  2016                Ukraine  2016-01-21
# 1501  13 Hours  2016   United Arab Emirates  2016-01-21
# 1502  13 Hours  2016                 Canada  2016-01-22
# 1503  13 Hours  2016            Philippines  2016-01-27
# ...

# %%
display(second)
# Out:
#           title  year                  name     type           character     n
# 16195  13 Hours  2016             Ben Affan    actor            Neighbor   NaN
# 16208  13 Hours  2016      Charaf Ben Affan    actor  CIA Annex Neighbor  54.0
# 17427  13 Hours  2016           Ayoub Aghil    actor        Sinister Man   NaN
# 17499  13 Hours  2016           Andr? Agius    actor   17 Feb Militiaman  44.0
# 22160  13 Hours  2016  Iskander El Hag Aisa    actor       North African  34.0
# 41460  13 Hours  2016         Yuric Allison    actor            Linguist  30.0
# 71317  13 Hours  2016            Sope Aluko  actress     BBC News Anchor   NaN
# 74939  13 Hours  2016      Elektra Anastasi  actress           CIA Agent   NaN

# %%
a = first.merge(second)

# %%
display(first.count())
display(second.count())
display(a.count())
# Out:
# title      54
# year       54
# country    54
# date       54
# dtype: int64
# title        8
# year         8
# name         8
# type         8
# character    8
# n            4
# dtype: int64
# title        432
# year         432
# country      432
# date         432
# name         432
# type         432
# character    432
# n            216
# dtype: int64

# %%
a[a['title'] == '13 Hours'].count()
# Out:
# title        432
# year         432
# country      432
# date         432
# name         432
# type         432
# character    432
# n            216
# dtype: int64

# %%
second.count()
# Out:
# title        8
# year         8
# name         8
# type         8
# character    8
# n            4
# dtype: int64

# %%
first.count()
# Out:
# title      54
# year       54
# country    54
# date       54
# dtype: int64

# %%
a.count()
# Out:
# title        432
# year         432
# country      432
# date         432
# name         432
# type         432
# character    432
# n            216
# dtype: int64
